# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
resp_time_df = pd.read_json(r"./data/ny_dyfi_plot_numresp.json")

# %%
resp_time_ds_df = pd.DataFrame(resp_time_df.datasets[0])

# %%
resp_time_ds_df
# Out:
#                                                    data      class
# 0     {'y': 1, 'x': 0.07, 't_seconds': 259, 't_absol...  histogram
# 1     {'y': 2, 'x': 0.07, 't_seconds': 260, 't_absol...  histogram
# 2     {'y': 3, 'x': 0.07, 't_seconds': 266, 't_absol...  histogram
# 3     {'y': 4, 'x': 0.07, 't_seconds': 270, 't_absol...  histogram
# 4     {'y': 5, 'x': 0.08, 't_seconds': 276, 't_absol...  histogram
# ...                                                 ...        ...
# 5623  {'y': 5624, 'x': 22.43, 't_seconds': 80766, 't...  histogram
# 5624  {'y': 5625, 'x': 22.54, 't_seconds': 81127, 't...  histogram
# 5625  {'y': 5626, 'x': 23.04, 't_seconds': 82959, 't...  histogram
# 5626  {'y': 5627, 'x': 23.23, 't_seconds': 83634, 't...  histogram
# 5627  {'y': 5628, 'x': 23.68, 't_seconds': 85265, 't...  histogram
#
# [5628 rows x 2 columns]

# %%
resp_time_plot_df = resp_time_ds_df.from_records(data=resp_time_ds_df.data)

# %%
resp_time_plot_df
# Out:
#          y      x  t_seconds           t_absolute
# 0        1   0.07        259  2023-02-06T11:20:08
# 1        2   0.07        260  2023-02-06T11:20:09
# 2        3   0.07        266  2023-02-06T11:20:15
# 3        4   0.07        270  2023-02-06T11:20:19
# 4        5   0.08        276  2023-02-06T11:20:25
# ...    ...    ...        ...                  ...
# 5623  5624  22.43      80766  2023-02-07T09:41:55
# 5624  5625  22.54      81127  2023-02-07T09:47:56
# 5625  5626  23.04      82959  2023-02-07T10:18:28
# 5626  5627  23.23      83634  2023-02-07T10:29:43
# 5627  5628  23.68      85265  2023-02-07T10:56:54
#
# [5628 rows x 4 columns]

# %%
resp_time_df
# Out:
#                                             datasets  \
# 0  {'data': [{'y': 1, 'x': 0.07, 't_seconds': 259...
#
#                           xlabel preferred_unit               ylabel  \
# 0  Time since earthquake (hours)          hours  Number of responses
#
#                      title  preferred_conversion
# 0  Responses vs. Time Plot                  3600

# %%
fig, ax = plt.subplots(figsize=(15, 10))
resp_time_plot_df.plot(kind='line', x='x', y='y', xticks=[0, 24], yticks=[0, 500, 1000, 1500, 2000, 3000, 4000, 5000, 5500], ax=ax)
plt.axis([0, 24, 0, 5500])
plt.show()
